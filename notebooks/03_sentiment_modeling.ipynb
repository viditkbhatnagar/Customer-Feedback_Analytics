# %%
# Sentiment Modeling - Customer Feedback Analytics
# This notebook trains and evaluates multiple sentiment analysis models.

# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import warnings
warnings.filterwarnings('ignore')

# Import custom modules
import sys
sys.path.append('..')
from src.models.sentiment_analyzer import SentimentAnalyzer

print("Libraries loaded successfully!")

# 1. Load Preprocessed Data
df = pd.read_csv('../data/processed/preprocessed_reviews.csv')
print(f"Loaded {len(df)} preprocessed reviews")

# Check class distribution
print("\nSentiment distribution:")
print(df['true_sentiment'].value_counts())

# 2. Prepare Data for Modeling
analyzer = SentimentAnalyzer()
X_train, X_test, y_train, y_test = analyzer.prepare_data(df)

print(f"Training set size: {len(X_train)}")
print(f"Test set size: {len(X_test)}")
print(f"\nClass distribution in training set:")
unique, counts = np.unique(y_train, return_counts=True)
for u, c in zip(unique, counts):
    print(f"  Class {u}: {c} ({c/len(y_train)*100:.1f}%)")

# 3. Train Traditional ML Models
tfidf_results = analyzer.train_tfidf_models(X_train, X_test, y_train, y_test)

for model_name, results in tfidf_results.items():
    print(f"\n{model_name.upper()} Results:")
    print(f"Accuracy: {results['accuracy']:.4f}")
    print("\nClassification Report:")
    print(results['report'])

# Confusion matrices
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for idx, (model_name, results) in enumerate(tfidf_results.items()):
    cm = confusion_matrix(y_test, results['predictions'])
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[idx],
                xticklabels=['Negative', 'Neutral', 'Positive'],
                yticklabels=['Negative', 'Neutral', 'Positive'])
    axes[idx].set_title(f'{model_name.upper()} Confusion Matrix')
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('Actual')
plt.tight_layout()
plt.show()

# 4. Feature Importance Analysis
rf_model = analyzer.models['random_forest']
with open('../models/sentiment/tfidf_vectorizer.pkl', 'rb') as f:
    vectorizer = pickle.load(f)
feature_names = vectorizer.get_feature_names_out()
importances = rf_model.feature_importances_
indices = np.argsort(importances)[-20:]  # Top 20 features
plt.figure(figsize=(10, 8))
plt.barh(range(len(indices)), importances[indices])
plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel('Feature Importance')
plt.title('Top 20 Most Important Features (Random Forest)')
plt.tight_layout()
plt.show()

# 5. Cross-Validation
X_full = vectorizer.fit_transform(df['cleaned_text'])
y_full = df['true_sentiment'].map({'positive': 2, 'negative': 0, 'neutral': 1}).values
cv_scores = cross_val_score(rf_model, X_full, y_full, cv=5, scoring='accuracy')
print("Cross-Validation Results (Random Forest):")
print(f"Scores: {cv_scores}")
print(f"Mean accuracy: {cv_scores.mean():.4f} (+/- {cv_scores.std() * 2:.4f})")

# 6. Model Comparison
comparison_df = analyzer.compare_models(tfidf_results)
print("Model Comparison:")
print(comparison_df)

# Visualize model comparison
metrics = ['Accuracy', 'Negative Precision', 'Neutral Precision', 'Positive Precision']
models = comparison_df['Model'].values

fig, ax = plt.subplots(figsize=(10, 6))
x = np.arange(len(models))
width = 0.2
for i, metric in enumerate(metrics):
    values = comparison_df[metric].values
    ax.bar(x + i * width, values, width, label=metric)
ax.set_xlabel('Models')
ax.set_ylabel('Score')
ax.set_title('Model Performance Comparison')
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels(models)
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# 7. Prediction Examples
sample_reviews = [
    "This product is absolutely amazing! Best purchase ever!",
    "Terrible quality, broke after one day. Very disappointed.",
    "It's okay, nothing special but works as expected.",
    "DO NOT BUY! Complete waste of money!!!",
    "Love it! Exceeded all my expectations. Highly recommend."
]
predictions, confidences = analyzer.predict_with_confidence(sample_reviews, 'random_forest')
print("Sample Predictions:")
print("=" * 60)
for review, pred, conf in zip(sample_reviews, predictions, confidences):
    print(f"Review: {review}")
    print(f"Prediction: {pred} (Confidence: {conf:.2%})")
    print("-" * 60)

# 8. Generate Final Predictions
best_model = comparison_df.iloc[0]['Model'].lower().replace(' ', '_')
print(f"Using best model: {best_model}")
all_predictions, all_confidences = analyzer.predict_with_confidence(df['cleaned_text'].values, best_model)
df['predicted_sentiment'] = all_predictions
df['confidence_score'] = all_confidences
output_path = '../data/processed/sentiment_predictions.csv'
df.to_csv(output_path, index=False)
print(f"\nPredictions saved to: {output_path}")

# 9. Error Analysis
misclassified = df[df['true_sentiment'] != df['predicted_sentiment']]
print(f"Total misclassifications: {len(misclassified)} ({len(misclassified)/len(df)*100:.1f}%)")
misclass_patterns = pd.crosstab(misclassified['true_sentiment'], misclassified['predicted_sentiment'])
print("\nMisclassification Patterns:")
print(misclass_patterns)
print("\nSample Misclassifications:")
for _, row in misclassified.sample(min(5, len(misclassified))).iterrows():
    print(f"\nReview: {row['review_text'][:100]}...")
    print(f"True: {row['true_sentiment']} | Predicted: {row['predicted_sentiment']} | Confidence: {row['confidence_score']:.2f}")
# Out:
# Libraries loaded successfully!
# Loaded 5063 preprocessed reviews
#
# Sentiment distribution:
# true_sentiment
# positive    2993
# negative    1394
# neutral      676
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 35
#      31 print(df['true_sentiment'].value_counts())
#      33 # 2. Prepare Data for Modeling
#      34 #analyzer = SentimentAnalyzer()
# ---> 35 X_train, X_test, y_train, y_test = analyzer.prepare_data(df)
#      37 print(f"Training set size: {len(X_train)}")
#      38 print(f"Test set size: {len(X_test)}")
#
# NameError: name 'analyzer' is not defined

# %%
# %pip install nltk
# %pip install textblob
# %pip install spacy
# %pip install textstat
# %pip install gensim
# %pip install torch
# %pip install transformers
# %pip install scikit-learn
# %pip install bertopic
# %pip install yake
# %pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (3.9.1)
# Requirement already satisfied: tqdm in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: joblib in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: click in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from nltk) (8.1.8)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textblob in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: tqdm in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: joblib in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from nltk>=3.9->textblob) (1.5.1)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (3.8.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (2.11.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (0.16.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (2.5.1)
# Requirement already satisfied: setuptools in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from spacy) (58.0.4)
# Requirement already satisfied: jinja2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (3.1.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (2.0.11)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (8.3.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (2.32.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (3.5.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (1.0.13)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.7.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Collecting numpy>=1.19.0
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: rich>=10.11.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.3.0.post1)
# Requirement already satisfied: wrapt in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from jinja2->spacy) (3.0.2)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: textstat in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (0.7.7)
# Requirement already satisfied: setuptools in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from textstat) (58.0.4)
# Requirement already satisfied: cmudict in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from textstat) (1.0.33)
# Requirement already satisfied: pyphen in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from textstat) (0.17.2)
# Requirement already satisfied: importlib-metadata>=5 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from cmudict->textstat) (8.5.0)
# Requirement already satisfied: importlib-resources>=5 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from cmudict->textstat) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=5->cmudict->textstat) (3.20.2)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (4.3.3)
# Collecting numpy<2.0,>=1.18.5
#   Using cached numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: wrapt in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (2.7.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch) (3.1.6)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch) (4.12.2)
# Requirement already satisfied: filelock in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch) (3.18.0)
# Requirement already satisfied: fsspec in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch) (2025.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from jinja2->torch) (3.0.2)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (4.53.2)
# Requirement already satisfied: packaging>=20.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (24.1)
# Requirement already satisfied: tqdm>=4.27 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: requests in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (0.33.4)
# Requirement already satisfied: filelock in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: pyyaml>=5.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (0.21.2)
# Requirement already satisfied: numpy>=1.17 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2025.7.14)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests->transformers) (3.4.2)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (1.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.5.1)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: bertopic in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (0.17.3)
# Requirement already satisfied: hdbscan>=0.8.29 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (0.8.40)
# Requirement already satisfied: pandas>=1.1.5 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (2.3.1)
# Requirement already satisfied: plotly>=4.7.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (6.2.0)
# Requirement already satisfied: tqdm>=4.41.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (4.67.1)
# Requirement already satisfied: numpy>=1.20.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (1.26.4)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (1.6.1)
# Requirement already satisfied: llvmlite>0.36.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (0.43.0)
# Requirement already satisfied: umap-learn>=0.5.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (0.5.9.post2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from bertopic) (5.0.0)
# Requirement already satisfied: joblib>=1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from hdbscan>=0.8.29->bertopic) (1.5.1)
# Requirement already satisfied: scipy>=1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from hdbscan>=0.8.29->bertopic) (1.13.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from plotly>=4.7.0->bertopic) (1.47.1)
# Requirement already satisfied: packaging in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from plotly>=4.7.0->bertopic) (24.1)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.15.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: Pillow in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=0.4.1->bertopic) (11.3.0)
# Requirement already satisfied: torch>=1.11.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=0.4.1->bertopic) (2.7.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.53.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.33.4)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.12.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.1.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.2)
# Requirement already satisfied: requests in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.4)
# Requirement already satisfied: filelock in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.18.0)
# Requirement already satisfied: networkx in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: sympy>=1.13.3 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.5.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.21.2)
# Requirement already satisfied: pynndescent>=0.5 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: numba>=0.51.2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.7.14)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yake in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (0.4.8)
# Requirement already satisfied: tabulate in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from yake) (0.9.0)
# Requirement already satisfied: click>=6.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from yake) (8.1.8)
# Requirement already satisfied: networkx in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from yake) (3.2.1)
# Requirement already satisfied: jellyfish in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from yake) (1.2.0)
# Requirement already satisfied: numpy in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from yake) (1.26.4)
# Requirement already satisfied: segtok in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from yake) (1.5.11)
# Requirement already satisfied: regex in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from segtok->yake) (2024.11.6)
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp39-cp39-macosx_11_0_arm64.whl (168 kB)
#      |████████████████████████████████| 168 kB 1.5 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from wordcloud) (3.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from matplotlib->wordcloud) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/viditkbhatnagar/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
